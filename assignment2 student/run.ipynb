# %%
import assignment
from importlib import reload
reload(assignment)
assignment.main("./CIFAR_data")
# Out:
# 0.5855

# %%
import assignment
from importlib import reload
reload(assignment)
assignment.main("./CIFAR_data")
# Out:
# 0.564

# %%
# Out:
# <class 'int'> <class 'float'>
