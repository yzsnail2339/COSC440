# %%
import structure_prediction
from importlib import reload
reload(structure_prediction)
data_folder = './'
structure_prediction.main(data_folder)
# Out:
# Debug info, shape of one data record:
# evolutionary shape= (5376,)
# id shape= (1,)
# primary shape= (256,)
# tertiary shape= (256, 3)
# primary_onehot shape= (256, 21)
# mask shape= (256,)
# true_distances shape= (256, 256)
# distance_mask shape= (256, 256)
# Value info of one data record, structure: tf.Tensor([1806.5  322.7 6882.9], shape=(3,), dtype=float32)
# Debug info, shape of one data record:
# evolutionary shape= (5376,)
# id shape= (1,)
# primary shape= (256,)
# tertiary shape= (256, 3)
# primary_onehot shape= (256, 21)
# mask shape= (256,)
# true_distances shape= (256, 256)
# distance_mask shape= (256, 256)
# Value info of one data record, structure: tf.Tensor([0. 0. 0.], shape=(3,), dtype=float32)
# Debug info, shape of one data record:
# evolutionary shape= (5376,)
# id shape= (1,)
# primary shape= (256,)
# tertiary shape= (256, 3)
# primary_onehot shape= (256, 21)
# mask shape= (256,)
# true_distances shape= (256, 256)
# distance_mask shape= (256, 256)
# Value info of one data record, structure: tf.Tensor([0. 0. 0.], shape=(3,), dtype=float32)
# Start of epoch 0
# train loss 261201395712.000 train mse loss 261201395712.000 validate mse loss 217936920576.000
# train loss 236419792896.000 train mse loss 236419792896.000 validate mse loss 191606996992.000
# train loss 207580200960.000 train mse loss 207580200960.000 validate mse loss 175068282880.000
# train loss 211922485248.000 train mse loss 211922485248.000 validate mse loss 140937773056.000
# train loss 110239006720.000 train mse loss 110239006720.000 validate mse loss 138418569216.000
# train loss 123644166144.000 train mse loss 123644166144.000 validate mse loss 106699489280.000
# train loss 189928882176.000 train mse loss 189928882176.000 validate mse loss 116934778880.000
# train loss 114950422528.000 train mse loss 114950422528.000 validate mse loss 87950336000.000
# train loss 90447724544.000 train mse loss 90447724544.000 validate mse loss 76516818944.000
# train loss 69520064512.000 train mse loss 69520064512.000 validate mse loss 80768196608.000
# train loss 60530647040.000 train mse loss 60530647040.000 validate mse loss 75560566784.000
# train loss 72400584704.000 train mse loss 72400584704.000 validate mse loss 58648817664.000
# train loss 57845805056.000 train mse loss 57845805056.000 validate mse loss 59939803136.000
# train loss 59696316416.000 train mse loss 59696316416.000 validate mse loss 59487055872.000
# train loss 57470353408.000 train mse loss 57470353408.000 validate mse loss 52659515392.000
# train loss 62154293248.000 train mse loss 62154293248.000 validate mse loss 52858720256.000
# train loss 62950785024.000 train mse loss 62950785024.000 validate mse loss 50074112000.000
# train loss 38591254528.000 train mse loss 38591254528.000 validate mse loss 50725851136.000
# train loss 41330069504.000 train mse loss 41330069504.000 validate mse loss 48795406336.000
# train loss 70389587968.000 train mse loss 70389587968.000 validate mse loss 49416167424.000
# train loss 48875163648.000 train mse loss 48875163648.000 validate mse loss 46127874048.000
# train loss 38579433472.000 train mse loss 38579433472.000 validate mse loss 48296136704.000
# train loss 31458893824.000 train mse loss 31458893824.000 validate mse loss 51449241600.000
# train loss 50464079872.000 train mse loss 50464079872.000 validate mse loss 47288541184.000
# train loss 38308130816.000 train mse loss 38308130816.000 validate mse loss 47563575296.000
# train loss 80633290752.000 train mse loss 80633290752.000 validate mse loss 59322273792.000
# train loss 54642114560.000 train mse loss 54642114560.000 validate mse loss 34691067904.000
# train loss 27273144320.000 train mse loss 27273144320.000 validate mse loss 43011665920.000
# train loss 75700371456.000 train mse loss 75700371456.000 validate mse loss 44279169024.000
# train loss 36360912896.000 train mse loss 36360912896.000 validate mse loss 39116247040.000
# train loss 49517715456.000 train mse loss 49517715456.000 validate mse loss 35472670720.000
# train loss 40311545856.000 train mse loss 40311545856.000 validate mse loss 42936340480.000
# train loss 43164925952.000 train mse loss 43164925952.000 validate mse loss 38136528896.000
# train loss 30859114496.000 train mse loss 30859114496.000 validate mse loss 34791985152.000
# train loss 27995766784.000 train mse loss 27995766784.000 validate mse loss 39295799296.000
# train loss 70310887424.000 train mse loss 70310887424.000 validate mse loss 38442434560.000
# train loss 40221143040.000 train mse loss 40221143040.000 validate mse loss 35521929216.000
# train loss 29696352256.000 train mse loss 29696352256.000 validate mse loss 35636400128.000
# train loss 39667933184.000 train mse loss 39667933184.000 validate mse loss 37801410560.000
# train loss 30751309824.000 train mse loss 30751309824.000 validate mse loss 37184475136.000
# train loss 37662269440.000 train mse loss 37662269440.000 validate mse loss 34645610496.000
# train loss 47716433920.000 train mse loss 47716433920.000 validate mse loss 34872090624.000
# train loss 30264428544.000 train mse loss 30264428544.000 validate mse loss 35807260672.000
# train loss 28276133888.000 train mse loss 28276133888.000 validate mse loss 37786083328.000
# train loss 63097126912.000 train mse loss 63097126912.000 validate mse loss 35928641536.000
# train loss 77912727552.000 train mse loss 77912727552.000 validate mse loss 39188819968.000
# train loss 36189478912.000 train mse loss 36189478912.000 validate mse loss 45484576768.000
# train loss 45000671232.000 train mse loss 45000671232.000 validate mse loss 36592742400.000
# train loss 41291284480.000 train mse loss 41291284480.000 validate mse loss 34907099136.000
# train loss 25913987072.000 train mse loss 25913987072.000 validate mse loss 39596249088.000
# train loss 18532978688.000 train mse loss 18532978688.000 validate mse loss 46306127872.000
# train loss 53462212608.000 train mse loss 53462212608.000 validate mse loss 42853478400.000
# train loss 86192734208.000 train mse loss 86192734208.000 validate mse loss 35360059392.000
# train loss 28970446848.000 train mse loss 28970446848.000 validate mse loss 41527631872.000
# train loss 64753004544.000 train mse loss 64753004544.000 validate mse loss 50442436608.000
# train loss 53232304128.000 train mse loss 53232304128.000 validate mse loss 41754202112.000
# train loss 51712421888.000 train mse loss 51712421888.000 validate mse loss 35425996800.000
# train loss 32355856384.000 train mse loss 32355856384.000 validate mse loss 37397622784.000
# train loss 38804529152.000 train mse loss 38804529152.000 validate mse loss 42875498496.000
# train loss 28737628160.000 train mse loss 28737628160.000 validate mse loss 45008777216.000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       3 reload(structure_prediction)
#       4 data_folder = './'
# ----> 5 structure_prediction.main(data_folder)
#
# File ~/yzsnail/final_project/structure_prediction.py:294, in main(data_folder)
#     290 print("Start of epoch %d" % (epoch,))
#     292 # Iterate over the batches of the dataset.
#     293 # strategy.run(train, args=(model, epoch_training_records, validate_records))
# --> 294 train(model, epoch_training_records, validate_records)
#     295 # strategy.run(test, args=(model, test_records, True))
#     296 test(model, test_records, True)
#
# File ~/yzsnail/final_project/structure_prediction.py:228, in train(model, train_dataset, validate_dataset, train_loss)
#     226 with tf.GradientTape() as tape:
#     227     tape.watch(inputs)
# --> 228     outputs = model(inputs, masks)
#     230     l = train_loss(outputs, labels, masks)
#     231     batch_loss = tf.reduce_sum(l)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/layers/layer.py:901, in Layer.__call__(self, *args, **kwargs)
#     899         outputs = super().__call__(*args, **kwargs)
#     900 else:
# --> 901     outputs = super().__call__(*args, **kwargs)
#     902 # Change the layout for the layer output if needed.
#     903 # This is useful for relayout intermediate tensor in the model
#     904 # to achieve the optimal performance.
#     905 distribution = distribution_lib.distribution()
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/yzsnail/final_project/structure_prediction.py:181, in ProteinStructurePredictor5.call(self, inputs, mask)
#     179 distances_bc = distances_bc * tf.expand_dims(mask, axis=-1)
#     180 x = tf.concat([x, x * distances_bc, distances_bc], axis=-1)
# --> 181 x = self.resnet(x)
#     182 x = x * tf.expand_dims(mask, axis=-1)
#     183 # x = self.dense2(x)
#     184 # x = self.layer1(x)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/layers/layer.py:901, in Layer.__call__(self, *args, **kwargs)
#     899         outputs = super().__call__(*args, **kwargs)
#     900 else:
# --> 901     outputs = super().__call__(*args, **kwargs)
#     902 # Change the layout for the layer output if needed.
#     903 # This is useful for relayout intermediate tensor in the model
#     904 # to achieve the optimal performance.
#     905 distribution = distribution_lib.distribution()
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/models/functional.py:175, in Functional.call(self, inputs, training, mask)
#     173         if mask is not None:
#     174             x._keras_mask = mask
# --> 175 outputs = self._run_through_graph(
#     176     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     177 )
#     178 return unpack_singleton(outputs)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/ops/function.py:171, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     169     outputs = call_fn(op, *args, **kwargs)
#     170 else:
# --> 171     outputs = op(*args, **kwargs)
#     173 # Update tensor_dict.
#     174 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/models/functional.py:560, in operation_fn.<locals>.call(*args, **kwargs)
#     554 if (
#     555     hasattr(operation, "_call_has_training_arg")
#     556     and operation._call_has_training_arg
#     557     and training is not None
#     558 ):
#     559     kwargs["training"] = training
# --> 560 return operation(*args, **kwargs)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/layers/layer.py:901, in Layer.__call__(self, *args, **kwargs)
#     899         outputs = super().__call__(*args, **kwargs)
#     900 else:
# --> 901     outputs = super().__call__(*args, **kwargs)
#     902 # Change the layout for the layer output if needed.
#     903 # This is useful for relayout intermediate tensor in the model
#     904 # to achieve the optimal performance.
#     905 distribution = distribution_lib.distribution()
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/models/sequential.py:212, in Sequential.call(self, inputs, training, mask)
#     210 def call(self, inputs, training=None, mask=None):
#     211     if self._functional:
# --> 212         return self._functional.call(inputs, training=training, mask=mask)
#     214     # Fallback: Just apply the layer sequence.
#     215     # This typically happens if `inputs` is a nested struct.
#     216     for layer in self.layers:
#     217         # During each iteration, `inputs` are the inputs to `layer`, and
#     218         # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     219         # end of each iteration `inputs` is set to `outputs` to prepare for
#     220         # the next layer.
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/models/functional.py:175, in Functional.call(self, inputs, training, mask)
#     173         if mask is not None:
#     174             x._keras_mask = mask
# --> 175 outputs = self._run_through_graph(
#     176     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     177 )
#     178 return unpack_singleton(outputs)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/ops/function.py:171, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     169     outputs = call_fn(op, *args, **kwargs)
#     170 else:
# --> 171     outputs = op(*args, **kwargs)
#     173 # Update tensor_dict.
#     174 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/models/functional.py:560, in operation_fn.<locals>.call(*args, **kwargs)
#     554 if (
#     555     hasattr(operation, "_call_has_training_arg")
#     556     and operation._call_has_training_arg
#     557     and training is not None
#     558 ):
#     559     kwargs["training"] = training
# --> 560 return operation(*args, **kwargs)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/layers/layer.py:901, in Layer.__call__(self, *args, **kwargs)
#     899         outputs = super().__call__(*args, **kwargs)
#     900 else:
# --> 901     outputs = super().__call__(*args, **kwargs)
#     902 # Change the layout for the layer output if needed.
#     903 # This is useful for relayout intermediate tensor in the model
#     904 # to achieve the optimal performance.
#     905 distribution = distribution_lib.distribution()
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/yzsnail/final_project/res_autoencoder.py:124, in Bottleneck.call(self, inputs, training)
#     122 identity = inputs
#     123 if self.downsample is not None:
# --> 124     identity = self.downsample(inputs)
#     126 x = self.conv1(inputs)
#     127 x = self.bn1(x, training=training)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/layers/layer.py:901, in Layer.__call__(self, *args, **kwargs)
#     899         outputs = super().__call__(*args, **kwargs)
#     900 else:
# --> 901     outputs = super().__call__(*args, **kwargs)
#     902 # Change the layout for the layer output if needed.
#     903 # This is useful for relayout intermediate tensor in the model
#     904 # to achieve the optimal performance.
#     905 distribution = distribution_lib.distribution()
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/models/sequential.py:212, in Sequential.call(self, inputs, training, mask)
#     210 def call(self, inputs, training=None, mask=None):
#     211     if self._functional:
# --> 212         return self._functional.call(inputs, training=training, mask=mask)
#     214     # Fallback: Just apply the layer sequence.
#     215     # This typically happens if `inputs` is a nested struct.
#     216     for layer in self.layers:
#     217         # During each iteration, `inputs` are the inputs to `layer`, and
#     218         # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     219         # end of each iteration `inputs` is set to `outputs` to prepare for
#     220         # the next layer.
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/models/functional.py:175, in Functional.call(self, inputs, training, mask)
#     173         if mask is not None:
#     174             x._keras_mask = mask
# --> 175 outputs = self._run_through_graph(
#     176     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     177 )
#     178 return unpack_singleton(outputs)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/ops/function.py:171, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     169     outputs = call_fn(op, *args, **kwargs)
#     170 else:
# --> 171     outputs = op(*args, **kwargs)
#     173 # Update tensor_dict.
#     174 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/models/functional.py:560, in operation_fn.<locals>.call(*args, **kwargs)
#     554 if (
#     555     hasattr(operation, "_call_has_training_arg")
#     556     and operation._call_has_training_arg
#     557     and training is not None
#     558 ):
#     559     kwargs["training"] = training
# --> 560 return operation(*args, **kwargs)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/layers/layer.py:880, in Layer.__call__(self, *args, **kwargs)
#     877 ####################
#     878 # 7. Call the layer.
#     879 try:
# --> 880     with self._open_name_scope():
#     881         current_scope = backend.get_autocast_scope()
#     882         new_scope = None
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/backend/tensorflow/core.py:649, in name_scope.__exit__(self, *args, **kwargs)
#     648 def __exit__(self, *args, **kwargs):
# --> 649     super().__exit__(*args, **kwargs)
#     650     if self._pop_on_exit:
#     651         self._tf_name_scope.__exit__(*args, **kwargs)
#
# File /home/software/anaconda3/envs/superpc-tf/lib/python3.11/site-packages/keras/src/backend/common/name_scope.py:56, in name_scope.__exit__(self, *args, **kwargs)
#      53     self._pop_on_exit = True
#      54     return self
# ---> 56 def __exit__(self, *args, **kwargs):
#      57     if self._pop_on_exit:
#      58         name_scope_stack = global_state.get_global_attribute(
#      59             "name_scope_stack"
#      60         )
#
# KeyboardInterrupt:
